# %% [markdown]
# # Caso práctico 1: Temas 1 y 2
# # Fundamentos de la criptografía + criptografía asimétrica
#
# ## Enunciado
#
# Una pequeña plataforma de mensajería necesita protegerse frente a interceptaciones y garantizar la integridad de los mensajes. El equipo de desarrollo propone dos alternativas: usar un cifrado simétrico con una clave compartida y, además, una clave pública para proteger la transmisión de la clave.
#
# El sistema en pruebas es el siguiente:
#
# - Alice y Bob comparten la clave simétrica `K = 13`.
# - Para cifrar un mensaje, usan `C = (M + K) mod 26` sobre letras del alfabeto.
# - Cada letra se representa con su índice en el alfabeto `A=0, B=1, ..., Z=25`.
# - Para comprobar integridad, calculan un hash SHA-256 del texto original.
# - Además, se estudia un escenario RSA sencillo para enviar una clave pública y cifrar un valor numérico.
#
# ### Contexto
# El objetivo no es solo cifrar, sino decidir qué propiedad se está garantizando: confidencialidad, integridad o autenticación. El sistema debe soportar intercambio de mensajes seguros entre dos participantes sin revelar el contenido a un atacante pasivo y sin permitir que un mensaje alterado pase por válido.
#
# ### Tareas
# 1. Cifra el mensaje `HELLO` con la clave compartida y explica el resultado.
# 2. Determina qué propiedad protege el cifrado simétrico y qué propiedad protege el hash.
# 3. Explica qué ocurre si un atacante modifica el ciphertext sin conocer la clave.
# 4. Compara el cifrado simétrico con la criptografía asimétrica en el contexto de transmisión de claves.
# 5. En un ejemplo RSA sencillo con `p = 5`, `q = 11`, `e = 3`, cifra el valor `M = 7` y comprueba la recuperación del mensaje.
# 6. Explica por qué la seguridad real de un sistema suele combinar cifrado simétrico y criptografía asimétrica.
# 7. Si Bob recibe `URYYB`, ¿es posible deducir la clave sin conocer la clave original? Justifica tu respuesta.
# 8. Diseña un pequeño protocolo de sesión para intercambiar una clave simétrica usando RSA y explica qué elemento aporta cada algoritmo.
# 9. Implementa en Python un ejemplo pequeño que combine cifrado afín, firma conceptual y cálculo RSA básico.

# %%
# Ejercicio: implementa aquí la lógica del caso
# Usa una clave simétrica y una función de hash simple para responder a las preguntas.

alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
def letter_to_index(ch):
    return alphabet.index(ch.upper())

def index_to_letter(i):
    return alphabet[i % 26]

print('Crea tu solución aquí')
