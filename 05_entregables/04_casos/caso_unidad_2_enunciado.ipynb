# %% [markdown]
# # Caso práctico 2: Temas 3 y 4
# # Computación cuántica + introducción a la criptografía post-cuántica
#
# ## Enunciado
#
# Una entidad financiera quiere evaluar el riesgo que supone la computación cuántica sobre sus protocolos actuales y preparar una transición hacia soluciones post-cuánticas. El sistema actual usa RSA y una capa TLS clásica para proteger la comunicación entre sucursales y clientes.
#
# El responsable de seguridad plantea un problema técnico: la infraestructura actual depende de protocolos que se apoyan en la dificultad de factorizar números grandes y resolver logaritmos discretos. Un avance cuántico podría erosionar esa base en pocos años. La organización quiere analizar la amenaza, comprender qué parte es realmente crítica y diseñar una estrategia prudente de transición.
#
# Los responsables del proyecto quieren responder a estas preguntas:
#
# 1. ¿Qué cambia al introducir un qubit y la superposición?
# 2. ¿Por qué Shor hace que RSA y ECC sean vulnerables?
# 3. ¿Qué papel juega Grover frente a una clave simétrica?
# 4. ¿Qué significa pasar a un esquema de intercambio de claves post-cuántico como ML-KEM?
# 5. ¿Cómo se puede representar un primer prototipo de intercambio de claves híbrido en Python?
#
# ### Tareas
# - Explica la diferencia entre bit clásico y qubit, y describe cómo la superposición cambia la forma de explorar soluciones.
# - Resume la amenaza de Shor para la factorización y explica por qué afecta a RSA.
# - Compara la seguridad de RSA con una clave simétrica de 128 bits frente a Grover y argumenta la diferencia entre reducir la fuerza bruta y romper directamente un esquema asimétrico.
# - Explica qué es un protocolo híbrido y por qué puede ser una transición segura hacia la post-cuántica.
# - Diseña un flujo de migración para un servicio bancario que actualmente usa TLS clásico y que necesita soportar una fase híbrida con seguridad cuántica.
# - Implementa un pequeño ejemplo de derivación de clave híbrida que combine una clave clásica y una clave post-cuántica, con una breve explicación de lo que se está generando.
# - Evalúa qué parte del sistema es más crítica: autenticación, intercambio de claves o cifrado del contenido.
# - Explica qué efecto tendría la migración en la experiencia de usuario y en el costo operativo del sistema.

# %%
# Implementa aquí la lógica del RSA simplificado
p = 5
q = 11
n = p * q
phi_n = (p - 1) * (q - 1)
e = 3
d = 27
print('RSA simplificado: n=', n, ', phi(n)=', phi_n)
