# %% [markdown]
# # Caso final de asignatura: migración a criptografía post-cuántica
#
# ## Enunciado
#
# Una universidad quiere modernizar su sistema de autenticación y firma de documentos para proteger la plataforma durante los próximos 15 años. El sistema actual usa:
#
# - RSA para intercambio de claves
# - AES-GCM para cifrado de contenido
# - ECDSA para firmas digitales
# - certificados X.509 para autenticación de usuarios y servicios
#
# La dirección quiere una propuesta razonada y un prototipo mínimo en Python para migrar a un modelo híbrido con soluciones post-cuánticas. Como la universidad tiene servicios de matrícula, correo, repositorio académico, validación de documentos y acceso a aulas virtuales, la migración debe mantener continuidad operativa y reducir el riesgo de interrupción.
#
# ### Contexto
# La institución debe decidir qué parte del sistema conviene migrar primero, qué mecanismos de compatibilidad son necesarios para periodos de transición y qué nivel de riesgo acepta durante la adopción. La solución debe tener en cuenta tanto el impacto operativo como la protección de la información académica y administrativa.
#
# ### Tareas
# 1. Identifica qué primitivas actuales son vulnerables frente a la computación cuántica y justifica por qué.
# 2. Propón un diseño híbrido con una KEM post-cuántica, una capa simétrica autenticada y un esquema de derivación de clave.
# 3. Explica qué algoritmo de firma elegirías y por qué, comparando al menos dos opciones válidas.
# 4. Analiza qué servicios de la universidad deben priorizarse en la migración y por qué.
# 5. Diseña un plan de migración con 5 pasos clave: evaluación, pruebas, despliegue, validación y retirada gradual del sistema clásico.
# 6. Implementa un prototipo en Python que simule una KEM híbrida con dos secretos, uno clásico y otro post-cuántico, y derive una clave final segura.
# 7. Explica qué riesgo se reduce con un certificado híbrido y qué ventaja aporta una transició n gradual.
# 8. Redacta una conclusión final con dos recomendaciones prácticas para la universidad.

# %%
# Prototipo mínimo: simula un protocolo híbrido de clave
# Usa una clave clásica y una clave post-cuántica ficticia para derivar una clave final

classical_secret = 'clave_clasica'
pqc_secret = 'clave_pqc'

def derive_key(k1, k2):
    return (k1 + ':' + k2).encode()

final_key = derive_key(classical_secret, pqc_secret)
print(final_key)
