# %% [markdown]
# # Caso práctico 3: Temas 5 y 6
# # NTRU + firmas y estándares post-cuánticos
#
# ## Enunciado
#
# Una universidad quiere revisar las opciones de migración a criptografía post-cuántica para sus sistemas de autenticación y cifrado. El equipo quiere comparar dos alternativas: NTRU (para intercambio de claves) y una firma basada en estándares modernos como ML-DSA / SLH-DSA. La institución tiene un sistema operativo con certificados X.509, autenticación de usuarios, firmas de documentos académicos y varios servicios internos que dependen de protocolos clásicos.
#
# El problema no es solo reemplazar un algoritmo por otro, sino adaptar la infraestructura completa a una nueva era de seguridad. La universidad necesita decidir cómo migrar de forma progresiva sin interrumpir la operación diaria y sin perder compatibilidad con sistemas heredados.
#
# ### Tareas
# 1. Explica en qué consiste la idea básica de NTRU y por qué se basa en operaciones con polinomios.
# 2. Compara NTRU con RSA y ECC en términos de seguridad, rendimiento y uso práctico.
# 3. Explica qué problema resuelve una firma post-cuántica y por qué no basta con cambiar solo el cifrado.
# 4. ¿Qué diferencias hay entre un KEM post-cuántico, una firma post-cuántica y un certificado híbrido?
# 5. Propón un plan de transición híbrido para una institución que aún usa certificados clásicos, con una secuencia de despliegue razonada.
# 6. Implementa un ejemplo pequeño de multiplicación de polinomios para entender la base algebraica de NTRU y explica qué papel juega ese tipo de cálculo dentro del esquema.
# 7. Identifica qué servicios de la universidad son más sensibles a una actualización de infraestructura: autenticación, firma de documentos, correo, portales o VPN.
# 8. Explica qué criterio usarías para decidir entre ML-DSA, SLH-DSA y una estrategia híbrida durante la migración.
# 9. Diseña una matriz de riesgos para una actualización gradual con una fase de prueba, una de despliegue y una de retirada de compatibilidad clásica.

# %%
# Implementa aquí el cálculo del periodo para N=15 y a=7
N = 15
a = 7
print('Calcula la secuencia y el periodo')
