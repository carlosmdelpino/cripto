# %% [markdown]
# # Práctica de la Unidad 1: Fundamentos de la criptografía
#
# ## Objetivo
#
# - Comprender los conceptos básicos de la criptografía.
# - Aplicar operaciones elementales de Python y aritmética modular.
# - Entender la utilidad de la función hash en la integridad de datos.
# - Relacionar la teoría con aplicaciones reales de seguridad digital.

# %% [markdown]
# ## Apartado 1. Objetivos de seguridad
#
# Explica, con tus palabras, qué significan los siguientes conceptos:
#
# - Confidencialidad
# - Integridad
# - Autenticación
# - No repudio

# %%
# Escribe aquí una respuesta breve en texto para cada objetivo de seguridad.

# %% [markdown]
# ## Apartado 2. Cálculo modular
#
# Calcula en Python los siguientes valores:
#
# - 23 mod 7
# - 29 mod 10
# - 43 mod 5
#
# Añade una explicación breve de lo que significa ser congruente módulo n.

# %%
# Calcula los restos de la división modular
# Ejemplo: print(23 % 7)

# %% [markdown]
# ## Apartado 3. Función hash
#
# Calcula el hash SHA-256 del texto `mensaje_secreto`.
#
# Explica qué propiedad de seguridad demuestra el hash y qué ocurre si cambias una letra del texto original.

# %%
import hashlib

mensaje = b'mensaje_secreto'
# Calcula el hash aquí
# print(hashlib.sha256(mensaje).hexdigest())

# %% [markdown]
# ## Apartado 4. Diferencia entre tipos de criptografía
#
# Completa la siguiente tabla:
#
# - Simétrica: ___
# - Asimétrica: ___
# - Híbrida: ___
#
# Explica cuál sería la más adecuada para cada caso:
#
# - cifrar un archivo grande;
# - distribuir una clave segura;
# - firmar un documento digital.

# %%
# Escribe aquí tus conclusiones sobre los tipos de criptografía.

# %% [markdown]
# ## Apartado 5. Reflexión final
#
# Escribe una reflexión breve (entre 150 y 250 palabras) sobre la importancia de la criptografía en el entorno digital actual. Debes comentar al menos tres situaciones de uso cotidiano.
#
# Ejemplos: banca online, infraestructura corporativa, correo electrónico, firma digital, autenticación en redes sociales.

# %%
# Redacción final de la práctica
# Escribe aquí tu reflexión final.

# %% [markdown]
# ## Cierre
#
# Resume la práctica en 3 ideas principales:
#
# 1. ______
# 2. ______
# 3. ______
